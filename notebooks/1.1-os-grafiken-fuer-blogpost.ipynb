# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
path_1 = Path('/Users/ole/Documents/Techlabs/SoSe-21-Team-10_Main/data/raw')
df_2 = pd.read_csv(path_1.joinpath('2000-2002.csv'), index_col='date', parse_dates=True)

# %%
plt.figure(figsize=(10,5), dpi=1200)
plt.scatter(df.index, df.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('score 2000-2002')
plt.savefig('figure_1.png', bbox_inches='tight', pad_inches=2)

# %%
df.score.unique()
# Out:
# array([   nan, 1.    , 2.    , 1.4905, 1.5019, 1.2818, 0.929 , 1.0481,
#        1.9995, 2.0391, 2.039 , 3.0946, 3.    , 3.9795, 4.7134, 5.    ,
#        4.7207, 4.7206, 4.    , 2.9851, 0.    , 0.9937, 0.9784, 0.5303,
#        0.2682, 0.2683, 0.5425, 0.4694, 0.3599, 0.0492, 0.2303, 0.6726,
#        0.5223, 0.99  , 1.5332, 1.4361, 1.6062, 1.4932, 1.4904, 2.8739,
#        2.0492])

# %%
df_months = df.iloc[0:91,:]

# %%
plt.figure(figsize=(10,5), dpi=1200)
plt.scatter(df_months.index, df_months.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('score 01.01.2000-31.03.2000')
plt.savefig('figure_2_high_DPI.png')

# %%
df.isnull().sum()
# Out:
# fips             0
# PRECTOT          0
# PS               0
# QV2M             0
# T2M              0
# T2MDEW           0
# T2MWET           0
# T2M_MAX          0
# T2M_MIN          0
# T2M_RANGE        0
# TS               0
# WS10M            0
# WS10M_MAX        0
# WS10M_MIN        0
# WS10M_RANGE      0
# WS50M            0
# WS50M_MAX        0
# WS50M_MIN        0
# WS50M_RANGE      0
# score          939
# dtype: int64

# %%
df.shape
# Out:
# (1096, 20)

# %%
df.head(21)
# Out:
#             fips  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# date
# 2000-01-01  1001     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 2000-01-02  1001     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2000-01-03  1001     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 2000-01-04  1001    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 2000-01-05  1001     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
# 2000-01-06  1001     0.01  101.31   3.49   4.99   -1.11   -1.07    12.89
# 2000-01-07  1001     0.01  101.37   3.93   5.99    0.55    0.58    14.51
# 2000-01-08  1001     1.02  100.77   5.71   8.69    5.33    5.34    15.78
# 2000-01-09  1001    16.19   99.88  11.18  15.73   15.45   15.45    19.60
# 2000-01-10  1001    21.23   99.78   7.77  13.61    9.59    9.60    17.65
# 2000-01-11  1001     1.33  100.40   6.63  11.48    7.84    7.84    18.88
# 2000-01-12  1001     0.17  100.59   8.39  13.02   11.36   11.36    20.74
# ...

# %%
df_months_kopie = df_months

# %%
df_mean= df_months_kopie.fillna(df_months_kopie.score.mean())

# %%
df_mean.tail()
# Out:
#             fips  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# date
# 2000-03-27  1001     4.08   98.90   8.91  14.53   11.78   11.78    22.22
# 2000-03-28  1001     0.00   99.07   7.46  14.58    9.10    9.10    24.09
# 2000-03-29  1001     1.77   99.65   8.12  14.82   10.34   10.35    21.28
# 2000-03-30  1001     7.52   99.52  11.90  19.60   16.55   16.54    26.70
# 2000-03-31  1001     0.14  100.14   8.85  17.07   12.09   12.09    25.05
#
#             T2M_MIN  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# date
# 2000-03-27     7.08      15.14  14.54   2.58       4.73       1.41
# 2000-03-28     5.37      18.71  14.53   2.97       5.13       1.60
# 2000-03-29     8.17      13.11  14.89   1.84       2.67       0.89
# 2000-03-30    13.35      13.35  19.65   2.18       3.20       1.02
# 2000-03-31     9.47      15.58  17.03   1.70       2.10       1.15
#
#             WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  WS50M_RANGE     score
# date
# ...

# %%
plt.figure(figsize=(10,5), dpi=1200)
plt.scatter(df_months.index, df_months.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('score 01.01.2000-31.03.2000 (with imputed mean)')
plt.savefig('figure_3.png')

# %%
df_months_kopie.head()
# Out:
#             fips  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# date
# 2000-01-01  1001     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 2000-01-02  1001     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2000-01-03  1001     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 2000-01-04  1001    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 2000-01-05  1001     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
#
#             T2M_MIN  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# date
# 2000-01-01    11.46       9.50  14.65   2.20       2.94       1.49
# 2000-01-02    12.61      10.18  16.60   2.52       3.43       1.83
# 2000-01-03    15.32       7.41  18.41   4.03       5.33       2.66
# 2000-01-04     2.16      15.92  11.31   3.84       5.67       2.08
# 2000-01-05    -2.66      13.48   2.65   1.60       2.50       0.52
#
#             WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  WS50M_RANGE     score
# date
# ...

# %%
df_intpol = df_2.iloc[0:91,:]

# %%
df_intpol.head()
# Out:
#             fips  PRECTOT      PS   QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# date
# 2000-01-01  1001     0.22  100.51   9.65  14.74   13.51   13.51    20.96
# 2000-01-02  1001     0.20  100.55  10.42  16.69   14.71   14.71    22.80
# 2000-01-03  1001     3.65  100.15  11.76  18.49   16.52   16.52    22.73
# 2000-01-04  1001    15.95  100.29   6.42  11.40    6.09    6.10    18.09
# 2000-01-05  1001     0.00  101.15   2.95   3.86   -3.29   -3.20    10.82
#
#             T2M_MIN  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# date
# 2000-01-01    11.46       9.50  14.65   2.20       2.94       1.49
# 2000-01-02    12.61      10.18  16.60   2.52       3.43       1.83
# 2000-01-03    15.32       7.41  18.41   4.03       5.33       2.66
# 2000-01-04     2.16      15.92  11.31   3.84       5.67       2.08
# 2000-01-05    -2.66      13.48   2.65   1.60       2.50       0.52
#
#             WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  WS50M_RANGE  score
# date
# ...

# %%
df_intpol.interpolate(method='time', inplace=True)
df_intpol.dropna(how='any', inplace=True)

# %%
df_intpol.head()
# Out:
#             fips  PRECTOT      PS  QV2M    T2M  T2MDEW  T2MWET  T2M_MAX  \
# date
# 2000-01-04  1001    15.95  100.29  6.42  11.40    6.09    6.10    18.09
# 2000-01-05  1001     0.00  101.15  2.95   3.86   -3.29   -3.20    10.82
# 2000-01-06  1001     0.01  101.31  3.49   4.99   -1.11   -1.07    12.89
# 2000-01-07  1001     0.01  101.37  3.93   5.99    0.55    0.58    14.51
# 2000-01-08  1001     1.02  100.77  5.71   8.69    5.33    5.34    15.78
#
#             T2M_MIN  T2M_RANGE     TS  WS10M  WS10M_MAX  WS10M_MIN  \
# date
# 2000-01-04     2.16      15.92  11.31   3.84       5.67       2.08
# 2000-01-05    -2.66      13.48   2.65   1.60       2.50       0.52
# 2000-01-06    -2.96      15.85   3.32   1.55       2.39       0.04
# 2000-01-07     0.63      13.88   5.69   2.31       3.28       1.59
# 2000-01-08     2.74      13.04   8.75   2.05       2.91       1.50
#
#             WS10M_RANGE  WS50M  WS50M_MAX  WS50M_MIN  WS50M_RANGE     score
# date
# ...

# %%
plt.figure(figsize=(10,5), dpi=1200)
plt.scatter(df_intpol.index, df_intpol.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('score 01.01.2000-31.03.2000 (with interpolated values)')
plt.savefig('figure_5.png')

# %%
plt.figure(figsize=(10,5), dpi=1200)
plt.subplot(1,2,1)
plt.scatter(df_months.index, df_months.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('Imputed Mean')

plt.subplot(1,2,2)
plt.scatter(df_intpol.index, df_intpol.score)
plt.xlabel('date')
plt.ylabel('score')
plt.title('Interpolation')
plt.savefig('figure_4.png')
